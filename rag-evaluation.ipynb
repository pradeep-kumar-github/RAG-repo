# %%
# from folder evaluation
from evaluation import test

# %%
tests = test.load_tests()

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.6666666666666666, ndcg=0.5543697530557483, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunks = evaluate_answer(example)

# %%
eval
# Out:
# AnswerEval(feedback='The generated answer generally aligns with the reference answer, although there are some minor discrepancies that affect its overall quality.', accuracy=4.0, completeness=5.0, relevance=5.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The generated answer generally aligns with the reference answer, although there are some minor discrepancies that affect its overall quality.
# 4.0
# 5.0
# 5.0

# %% [markdown]
# ### run in terminal: uv run evaluator.py
#
# run and check
#
# step 2:
#
# change the RETRIEVAL_K in answer.py : 5 -> 10
# change the chunk_size in ingest.py : 1000 -> 500
# run in terminal: uv run ingest.py
# run and check
#
# step 3:
#
# RETRIEVAL_K -> 3
# chunk_size -> 1667
# run in terminal: uv run ingest.py
# run and check
#
# step 4:
#
# in ingest.py import : from langchain_text_splitters import RecursiveCharacterTextSplitter, MarkdownTextSplitter
# instead of :     text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 200)
# use :     text_splitter = MarkdownTextSplitter()
# MarkdownTextSplitter automatically creates chunksize
# run in terminal: uv run ingest.py
# run and check
# undo this change.
#
# step 5:
#
# change openai embedding models for better results
# text-embedding-3-small and text-embedding-3-large
